# %%
from lib.datasets import download_stock_price
import yfinance as yf

# %%
download_stock_price(ticker='AAPL')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-01    0.936384    1.084821    0.772321    0.926339    0.784238
# 2000-02-01    0.928571    1.070871    0.866071    1.023438    0.866442
# 2000-03-01    1.058594    1.342634    1.017857    1.212612    1.026597
# 2000-04-01    1.209821    1.245536    0.936384    1.107701    0.937779
# 2000-05-01    1.114955    1.127232    0.729911    0.750000    0.634950
# ...                ...         ...         ...         ...         ...
# 2023-08-01  196.240005  196.729996  171.960007  187.869995  187.130997
# 2023-09-01  189.490005  189.979996  167.619995  171.210007  170.766846
# 2023-10-01  171.220001  182.339996  165.669998  170.770004  170.327972
# 2023-11-01  171.000000  192.929993  170.119995  189.949997  189.458313
# 2023-12-01  190.330002  199.619995  187.449997  192.529999  192.284637
#
#                  Volume
# Date
# ...

# %%
data_config = {
    'ticker' : '^GSPC',
    'interval' : '1mo',
    'column' : 1,  #Open
    'window_size' : 3,
    'dir' : 'datasets',
    'subdir' : 'stock',
}

# %%
from lib.datasets import get_stock_price
AAPL_pt = get_stock_price(data_config)
# Out:
# Rolled data for training, shape torch.Size([286, 3, 1])
# tensor([[[ 0.0000e+00],
#          [-5.0904e-02],
#          [-6.9988e-02]],
#
#         [[ 0.0000e+00],
#          [-2.0108e-02],
#          [ 7.4667e-02]],
#
#         [[ 0.0000e+00],
#          [ 9.6720e-02],
#          [ 6.2946e-02]],
#
#         [[ 0.0000e+00],
#          [-3.0796e-02],
#          [-5.2036e-02]],
#
#         [[ 0.0000e+00],
#          [-2.1915e-02],
#          [ 1.4940e-03]],
#
#         [[ 0.0000e+00],
#          [ 2.3934e-02],
#          [ 7.2012e-03]],
#
#         [[ 0.0000e+00],
#          [-1.6341e-02],
#          [ 4.3366e-02]],
#
#         [[ 0.0000e+00],
#          [ 6.0699e-02],
#          [ 3.9768e-03]],
#
#         [[ 0.0000e+00],
#          [-5.3476e-02],
#          [-5.8168e-02]],
#
#         [[ 0.0000e+00],
#          [-4.9564e-03],
#          [-8.4628e-02]],
#
#         [[ 0.0000e+00],
#          [-8.0069e-02],
#          [-7.6340e-02]],
#
#         [[ 0.0000e+00],
# ...

# %%
df = yf.download('AAPL', start='2000-01-01', end='2023-12-31', interval='1mo')
print(df[df.columns[0]])
print(df[df.columns[1]].shape)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2000-01-01      0.936384
# 2000-02-01      0.928571
# 2000-03-01      1.058594
# 2000-04-01      1.209821
# 2000-05-01      1.114955
#                  ...
# 2023-08-01    196.240005
# 2023-09-01    189.490005
# 2023-10-01    171.220001
# 2023-11-01    171.000000
# 2023-12-01    190.330002
# Name: Open, Length: 288, dtype: float64
# (288,)

# %%
from lib.utils import to_numpy
NV_open = df[df.columns[0]].to_numpy(dtype='float')
print(NV_open.shape)
print(NV_open)
# Out:
# (288,)
# [  0.93638402   0.92857099   1.05859399   1.20982099   1.11495495
#    0.72991103   0.93080401   0.89843798   1.09486604   0.47656301
#    0.34709799   0.30357099   0.265625     0.36941999   0.31808001
#    0.39446399   0.45375001   0.35946399   0.42214301   0.33946401
#    0.33035699   0.27660701   0.31517899   0.37607101   0.39375001
#    0.434643     0.39160699   0.41749999   0.43375      0.41767901
#    0.31625      0.26982099   0.25874999   0.26053599   0.28464299
#    0.28392899   0.25642899   0.257321     0.26803601   0.253571
#    0.254464     0.32321399   0.33696401   0.375        0.404643
#    0.36982101   0.40767899   0.375714     0.384821     0.40107101
#    0.43035701   0.48017901   0.464286     0.49625      0.57321399
#    0.556786     0.61250001   0.69857103   0.9375       1.210536
#    1.15678596   1.375893     1.60678601   1.503214     1.29321396
#    1.42464304   1.31535697   1.52035701   1.67857099   1.934286
# ...
